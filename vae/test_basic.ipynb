# %%
import torch.utils
import torch.distributions
from utils import *
from models import *

root = '.'

# %%
torch.manual_seed(0)
plt.rcParams['figure.dpi'] = 200
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
dataset = download_dataset()

# %% [markdown]
# # Test optimizer

# %%
latent_dims = 2
batch_size = 128
epochs = 30
lr = 0.001
optimizers = [torch.optim.RAdam, torch.optim.NAdam, torch.optim.AdamW, torch.optim.Adam, torch.optim.RMSprop]
loss_func = loss_mse
l1_weight = 0.0
b_value = 1
use_kl = True
model_name = 'vae'
exp_title = 'test_optimizer'

data = get_dataloader(dataset, batch_size)
for exp_index, optimizer in enumerate(optimizers):

    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 5905.0645
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 4981.9384
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 4782.7605
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 4656.7097
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 4563.5873
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 4498.5296
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 4445.0016
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 4399.1904
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 4361.8043
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 4331.0252
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 4304.2264
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 4280.7644
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test func_loss
# kowyrgencja włacz wyłącz, mse włącz wyłacz i l1

# %%
latent_dims = 2
batch_size = 128
epochs = 30
lr = 0.001
optimizer = torch.optim.Adam
loss_funcs = [loss_mse, loss_0]
kls = [True, False]
l1_weight = 0.0
b_value = 1
model_name = 'vae'
exp_title = 'test_loss'

data = get_dataloader(dataset, batch_size)
exp_index = 0
for use_kl in kls:
  for loss_func in loss_funcs:
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
    exp_index +=1
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 5749.7110
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 4901.6498
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 4745.2548
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 4643.6435
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 4564.9887
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 4506.5002
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 4457.7776
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 4418.0754
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 4383.3031
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 4354.3144
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 4328.8652
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 4305.8128
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test l1

# %%
latent_dims = 2
batch_size = 128
epochs = 30
lr = 0.001
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weights = [0.00, 0.01, 0.003, 0.001, 0.005, 0.0001]
model_name = 'vae'
exp_title = 'test_l1'

data = get_dataloader(dataset, batch_size)
exp_index = 0
for l1_weight in l1_weights:
  model = VariationalAutoencoder(latent_dims).to(device)
  do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
  exp_index +=1
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 7042.6475
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 6778.9921
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 6773.5700
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 6769.6144
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 6766.7761
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 6762.7121
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 6760.6347
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 6758.6498
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 6757.2157
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 6756.0129
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 6754.9860
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 6754.6569
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test BVAE & AE

# %%
latent_dims = 2
batch_size = 128
epochs = 30
lr = 0.001
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weight = 0.00
exp_title = 'test_bvae_ae'
data = get_dataloader(dataset, batch_size)

model_name ='ae'
b_value = 1
exp_index = 0
model = Autoencoder(latent_dims).to(device)
do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
exp_index += 1

model_name = 'bvae'
b_values = [0, 1, 2, 4, 5, 10, 20]

for b_value in b_values:
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
    exp_index += 1
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 5618.0933
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 4783.3621
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 4620.1467
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 4511.2736
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 4424.9839
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 4358.5510
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 4303.3772
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 4257.0685
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 4219.3403
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 4183.4184
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 4158.2199
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 4130.4861
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test batch_size

# %%
latent_dims = 2
batch_sizes = [8, 32, 128, 512, 1024]
epochs = 30
lr = 0.001
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weight = 0.00
b_values = 1
model_name = 'vae'
exp_title = 'test_batch'

for exp_index, batch_size in enumerate(batch_sizes):
    data = get_dataloader(dataset, batch_size)
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
# Out:
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 425.9170
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 422.6892
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 422.3990
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 422.2872
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 422.2116
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 422.1708
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 422.1259
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 422.0830
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 422.0859
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 422.0592
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 422.0394
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 422.0197
#   0%|          | 0/7500 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test latent_size

# %%
latent_dims_list = [1, 2, 4, 8, 16]

batch_size = 128
epochs = 50
lr = 0.001
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weight = 0.00
b_values = 1
model_name = 'vae'
exp_title = 'test_latent'

data = get_dataloader(dataset, batch_size)
for exp_index, latent_dims in enumerate(latent_dims_list):
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/50], avg_loss: 6997.4127
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/50], avg_loss: 6776.9751
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/50], avg_loss: 6771.6111
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/50], avg_loss: 6768.7241
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/50], avg_loss: 6766.2352
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/50], avg_loss: 6763.6879
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/50], avg_loss: 6761.7327
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/50], avg_loss: 6759.0519
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/50], avg_loss: 6757.6986
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/50], avg_loss: 6757.6557
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/50], avg_loss: 6755.8553
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/50], avg_loss: 6755.6302
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Test epochs

# %%
latent_dims = 2
batch_size = 128
epochses = [5, 20, 30, 50, 100]
lr = 0.001
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weight = 0.00
b_values = 1
model_name = 'vae'
exp_title = 'test_epochs'

data = get_dataloader(dataset, batch_size)
for exp_index, epochs in enumerate(epochses):
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/5], avg_loss: 7025.8332
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/5], avg_loss: 6778.5042
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/5], avg_loss: 6773.5071
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/5], avg_loss: 6769.5825
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/5], avg_loss: 6764.1641
# Saving model 0
# ...

# %% [markdown]
# # Test lr

# %%
latent_dims = 2
batch_size = 128
epochs = 30
lrs = [0.0001, 0.0005, 0.001, 0.003, 0.008]
optimizer = torch.optim.Adam
loss_func = loss_mse
use_kl = True
l1_weight = 0.00
b_values = 1
model_name = 'vae'
exp_title = 'test_lr'

data = get_dataloader(dataset, batch_size)
for exp_index, lr in enumerate(lrs):
    model = VariationalAutoencoder(latent_dims).to(device)
    do_exp(latent_dims, batch_size, epochs, lr, optimizer, loss_func, l1_weight, model_name, exp_title, data, exp_index, b_value, model, device, use_kl, root)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [1/30], avg_loss: 9115.6732
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [2/30], avg_loss: 6908.2105
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [3/30], avg_loss: 6806.5210
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [4/30], avg_loss: 6778.7340
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [5/30], avg_loss: 6767.3049
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [6/30], avg_loss: 6761.2629
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [7/30], avg_loss: 6757.1064
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [8/30], avg_loss: 6755.2318
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [9/30], avg_loss: 6753.8820
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [10/30], avg_loss: 6752.6752
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [11/30], avg_loss: 6751.0933
#   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch [12/30], avg_loss: 6751.1108
#   0%|          | 0/469 [00:00<?, ?it/s]
# ...
